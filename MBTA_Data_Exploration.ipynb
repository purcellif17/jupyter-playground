# %% [markdown]
# # Playing around with MBTA data

# %%
import os
import pandas as pd
from datetime import datetime

date = datetime.today().strftime('%Y%m%d')

gtfs_fold = os.path.join(os.path.expanduser('~'),"OneDrive","Documents","ArcGIS","Projects","MBTA_Overview","GTFS","GTFS_raw",f"{date}_GTFS")

# %%
df = pd.read_csv(gtfs_fold+'\\stops.txt')
df
# Out:
#                   stop_id  stop_code  \
# 0                       1        1.0
# 1                      10       10.0
# 2                   10000    10000.0
# 3                   10003    10003.0
# 4                   10005    10005.0
# ...                   ...        ...
# 9095          place-wtcst        NaN
# 9096                74613    74613.0
# 9097                74615    74615.0
# 9098  door-wtcst-congress        NaN
# 9099       door-wtcst-wtc        NaN
#
#                                         stop_name  \
# 0                    Washington St opp Ruggles St
# 1                   Theo Glynn Way @ Newmarket Sq
# 2                        Tremont St opp Temple Pl
# 3                        Albany St opp Randall St
# 4                      Albany St opp E Concord St
# ...                                           ...
# 9095                           World Trade Center
# 9096                           World Trade Center
# 9097                           World Trade Center
# ...

# %%
df.dropna(subset=['stop_lat', 'stop_lon'])
df
# Out:
#                   stop_id  stop_code  \
# 0                       1        1.0
# 1                      10       10.0
# 2                   10000    10000.0
# 3                   10003    10003.0
# 4                   10005    10005.0
# ...                   ...        ...
# 9095          place-wtcst        NaN
# 9096                74613    74613.0
# 9097                74615    74615.0
# 9098  door-wtcst-congress        NaN
# 9099       door-wtcst-wtc        NaN
#
#                                         stop_name  \
# 0                    Washington St opp Ruggles St
# 1                   Theo Glynn Way @ Newmarket Sq
# 2                        Tremont St opp Temple Pl
# 3                        Albany St opp Randall St
# 4                      Albany St opp E Concord St
# ...                                           ...
# 9095                           World Trade Center
# 9096                           World Trade Center
# 9097                           World Trade Center
# ...

# %%
df.to_csv(gtfs_fold+'\\stops.txt',index=False)
