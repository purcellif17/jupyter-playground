# %% [markdown]
# # Playing around with MBTA data

# %%
import pandas as pd
import jsonapi_requests

# %%
api = jsonapi_requests.Api.config({
    'API_ROOT': 'https://api-v3.mbta.com/',
    'TIMEOUT': 1,
})
route = 'Green-B'
vehicles = api.endpoint('vehicles')
vehicles

# %%
response = vehicles.get()
response
# Out:
# <ApiResponse({'data': [{'attributes': {'bearing': 0, 'current_status': 'IN_TRANSIT_TO', 'current_stop_sequence': 23, 'direction_id': 1, 'label': '1869', 'latitude': 42.33278661, 'longitude': -71.080797779, 'occupancy_status': 'MANY_SEATS_AVAILABLE', 'speed': None, 'updated_at': '2020-09-24T16:26:13-04:00'}, 'id': 'y1869', 'links': {'self': '/vehicles/y1869'}, 'relationships': {'route': {'data': {'id': '1', 'type': 'route'}}, 'stop': {'data': {'id': '62', 'type': 'stop'}}, 'trip': {'data': {'id': '45683858', 'type': 'trip'}}}, 'type': 'vehicle'}, {'attributes': {'bearing': 0, 'current_status': 'IN_TRANSIT_TO', 'current_stop_sequence': 14, 'direction_id': 0, 'label': '0546', 'latitude': 42.33455711, 'longitude': -71.12256768, 'occupancy_status': None, 'speed': None, 'updated_at': '2020-09-24T16:26:00-04:00'}, 'id': 'y0546', 'links': {'self': '/vehicles/y0546'}, 'relationships': {'route': {'data': {'id': '65', 'type': 'route'}}, 'stop': {'data': {'id': '1287', 'type': 'stop'}}, 'trip': 
# ...

# %%
response.data
# Out:
# DynamicCollection.from_data([{'type': 'vehicle', 'id': 'y1869', 'attributes': {'bearing': 0, 'current_status': 'IN_TRANSIT_TO', 'current_stop_sequence': 23, 'direction_id': 1, 'label': '1869', 'latitude': 42.33278661, 'longitude': -71.080797779, 'occupancy_status': 'MANY_SEATS_AVAILABLE', 'speed': None, 'updated_at': '2020-09-24T16:26:13-04:00'}, 'relationships': {'route': {'data': {'type': 'route', 'id': '1'}}, 'stop': {'data': {'type': 'stop', 'id': '62'}}, 'trip': {'data': {'type': 'trip', 'id': '45683858'}}}, 'links': {'self': '/vehicles/y1869'}}, {'type': 'vehicle', 'id': 'y0546', 'attributes': {'bearing': 0, 'current_status': 'IN_TRANSIT_TO', 'current_stop_sequence': 14, 'direction_id': 0, 'label': '0546', 'latitude': 42.33455711, 'longitude': -71.12256768, 'occupancy_status': None, 'speed': None, 'updated_at': '2020-09-24T16:26:00-04:00'}, 'relationships': {'route': {'data': {'type': 'route', 'id': '65'}}, 'stop': {'data': {'type': 'stop', 'id': '1287'}}, 'trip': {'data': {'ty
# ...
